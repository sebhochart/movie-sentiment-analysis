# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd

from movie_sentiment.processing.arcs import generate_all_arcs
from movie_sentiment.params import *
import pickle
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
generate_all_arcs()
# Out:
# 2858/2858 movies arcs generatedSaving in pickle file
# Saved in pickle file
# {'Dark City': array([-0.238068, -0.248804, -0.263988, -0.276264, -0.272024, -0.264944,
#         -0.264944, -0.27105 , -0.277852, -0.292224, -0.279996, -0.255536,
#         -0.2518  , -0.254958, -0.2378  , -0.239854, -0.229888, -0.233448,
#         -0.225082, -0.229032, -0.239528, -0.244266, -0.238346, -0.245982,
#         -0.251996, -0.273098, -0.28012 , -0.246718, -0.26569 , -0.267506,
#         -0.28211 , -0.252564, -0.263812, -0.240938, -0.217072, -0.220806,
#         -0.186274, -0.195704, -0.173022, -0.18576 , -0.194494, -0.166654,
#         -0.156236, -0.156308, -0.154122, -0.154632, -0.161246, -0.16393 ,
#         -0.168426, -0.191028, -0.205956, -0.207674, -0.205262, -0.213256,
#         -0.217558, -0.202076, -0.219796, -0.202276, -0.18495 , -0.189926,
#         -0.196024, -0.215548, -0.226394, -0.22003 , -0.226238, -0.23609 ,
# ...

# %%
with open(IDS_PICKLE_FILE, 'rb') as handle:
    ids = pickle.load(handle)

# %%
movie_names = pd.DataFrame([id for id in ids.values()])

# %%
counts = pd.DataFrame(movie_names[0].value_counts())

# %%
len(counts[counts['count'] > 1])
# Out:
# 41
